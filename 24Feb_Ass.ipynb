# %% [markdown]
# # Qus 1

# %%
# read_csv(): Used to read data from a CSV file into a pandas DataFrame.
import pandas as pd
df=pd.read_csv("services.csv")
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %% [raw]
# head(): Returns the first n rows of a DataFrame. By default, it returns the first 5 rows.

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %% [markdown]
# tail(): Returns the last n rows of a DataFrame. By default, it returns the last 5 rows.

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %% [markdown]
# info(): Provides a concise summary of a DataFrame including the index dtype, column dtypes, non-null values, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              21 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
#  11  funding_sources          21 non-null     object
#  12  interpretation_services  1 non-null      object
#  13  keywords                 21 non-null     object
# ...

# %% [markdown]
# describe(): Generates descriptive statistics that summarize the central tendency, dispersion, and shape of a DataFrame's distribution of numeric data.

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %% [markdown]
# # Qus 2

# %%
def reindex(df):
    df_reset=df.reset_index(drop=True)
    
    new_index_values=[i* 2+1 for i in range(len(df_reset))]
    df_reset.index=new_index_values
    
    return df_reset

new_df=reindex(df)
new_df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 1   1            1         NaN               NaN            NaN
# 3   2            2         NaN               NaN            NaN
# 5   3            3         NaN               NaN            NaN
# 7   4            4         NaN               NaN            NaN
# 9   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 1                   Walk in or apply by phone.
# 3           Apply by phone for an appointment.
# 5  Phone for information (403-4300 Ext. 4322).
# 7                              Apply by phone.
# 9                       Phone for information.
#
#                                             audience  \
# 1  Older adults age 55 or over, ethnic minorities...
# 3       Residents of San Mateo County age 55 or over
# 5  Older adults age 55 or over who can benefit fr...
# 7  Parents, children, families with problems of c...
# ...

# %% [markdown]
# # Qus 3

# %%
df=pd.DataFrame({"Values":[10,20,30,40,50]})
values_column=df["Values"]

# %%
sum=values_column[:3].sum()

# %%
sum
# Out:
# 60

# %% [markdown]
# # Qus=4

# %%
df=pd.DataFrame({"Text":["This is a Sample ","Another example ","Python is easy language","my name is Syed Zaid Ali"]})

# %%
df["word_count"]=df["Text"].apply(lambda x:len(x.split()))

# %%
df
# Out:
#                        Text  word_count
# 0         This is a Sample            4
# 1          Another example            2
# 2   Python is easy language           4
# 3  my name is Syed Zaid Ali           6

# %% [markdown]
# # Qus 5

# %% [raw]
# # DataFrame.size:
#           it returns the total number of elements in the DataFrame,i.e.,the             number of cells in the DataFrame.
#           it is calculated as the product of the number of rows and the                 number of columns in the DataFrame.
#
# # DataFrame.shape:
#           it returns a tuple representing the dimensions of the DataFrame.
#           it returns the number of rows and columns in the DataFrame

# %% [markdown]
# # Qus 6

# %%
df=pd.read_excel("LUSID Excel - Setting up your market data.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# # Qus 7

# %%
df=pd.DataFrame({"Email":["john.doe@example.com","zaid.ali@example.com","ali@gmail.com"]})

# %%
df["Username"]=df["Email"].str.split("@").str[0]

# %%
df
# Out:
#                   Email  Username
# 0  john.doe@example.com  john.doe
# 1  zaid.ali@example.com  zaid.ali
# 2         ali@gmail.com       ali

# %% [markdown]
# # Qus 8

# %%
df=pd.DataFrame({"A":[3,8,6,2,9],
                 "B":[5,2,9,3,1],
                 "C":[1,7,4,5,2]})

# %%
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
selected=df[(df["A"]>5) & (df["B"]<10)]

# %%
selected
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# # Qus.9

# %%
df=pd.DataFrame({"Values":[10,20,30,40,50,60]})

# %%
df["Values"].mean()
# Out:
# 35.0

# %%
df["Values"].median()
# Out:
# 35.0

# %%
df["Values"].std()
# Out:
# 18.708286933869708

# %% [markdown]
# # Qus 10

# %%
import pandas as pd

# %%
data={"date":pd.date_range(start="2024-03-01",end="2024-03-10"),
      "Sales":[100,200,300,130,140,110,170,180,300,400]}

# %%
df=pd.DataFrame(data)
df.sort_values(by="date",inplace=True)

# %%
df["MovingAverage"]=df["Sales"].rolling(window=7,min_periods=1).mean()

# %%
df
# Out:
#         date  Sales  MovingAverage
# 0 2024-03-01    100     100.000000
# 1 2024-03-02    200     150.000000
# 2 2024-03-03    300     200.000000
# 3 2024-03-04    130     182.500000
# 4 2024-03-05    140     174.000000
# 5 2024-03-06    110     163.333333
# 6 2024-03-07    170     164.285714
# 7 2024-03-08    180     175.714286
# 8 2024-03-09    300     190.000000
# 9 2024-03-10    400     204.285714

# %% [markdown]
# # Qus 11

# %%
dates=pd.date_range(start="2023-01-01",end="2023-01-05")
df=pd.DataFrame({"Date":dates})

# %%
df["Weekday"]=df["Date"].dt.strftime("%A")

# %%
df
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# # Qus 12

# %%
dates=pd.date_range(start="2023-01-01",end="2023-02-28")
df=pd.DataFrame({"Date":dates})

# %%
df['Date'] = pd.to_datetime(df['Date'])
start_date="2023-01-01"
end_date="2023-01-31"

# %%
selected=df[(df["Date"]>=start_date)&(df["Date"]<=end_date)]

# %%
selected
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# 22 2023-01-23
# 23 2023-01-24
# 24 2023-01-25
# 25 2023-01-26
# 26 2023-01-27
# 27 2023-01-28
# 28 2023-01-29
# 29 2023-01-30
# 30 2023-01-31

# %% [markdown]
# # Qus 13

# %% [markdown]
# The first and foremost necessary library that needs to be imported to use the basic functions of pandas is pandas itself. You import it using the import keyword

# %%
import pandas as pd
